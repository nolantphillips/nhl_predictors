# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
from nhlpy import NHLClient

client = NHLClient()

# %% [markdown]
# # Goal of Project:
# ## Initially
# - Predict winner of games, predict scores, spreads
# - Need team information, rolling team info, special teams features, starting goalie features, Home/Away, days of rest, travel info?
# - Matchup features and play style
# - Standings info
#
# ## Later
# - Predict live chances of winning for a team
# - Predict player performance?
# - Provide insight into team and player performance
# - Combine with NFL modeling for one stop shop?

# %%
# Explore types of data needed

# Can get season long info for teams here
client.stats.team_summary("20252026", "20252026")
# Out:
# [{'faceoffWinPct': 0.493202,
#   'gamesPlayed': 21,
#   'goalsAgainst': 48,
#   'goalsAgainstPerGame': 2.28571,
#   'goalsFor': 87,
#   'goalsForPerGame': 4.14285,
#   'losses': 1,
#   'otLosses': 5,
#   'penaltyKillNetPct': 0.880597,
#   'penaltyKillPct': 0.865672,
#   'pointPct': 0.83333,
#   'points': 35,
#   'powerPlayNetPct': 0.1375,
#   'powerPlayPct': 0.1625,
#   'regulationAndOtWins': 15,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 26.14285,
#   'shotsForPerGame': 33.42857,
#   'teamFullName': 'Colorado Avalanche',
#   'teamId': 21,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 15,
#   'winsInRegulation': 14,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.498144,
#   'gamesPlayed': 21,
#   'goalsAgainst': 60,
#   'goalsAgainstPerGame': 2.85714,
#   'goalsFor': 76,
#   'goalsForPerGame': 3.61904,
#   'losses': 5,
#   'otLosses': 2,
#   'penaltyKillNetPct': 0.833333,
#   'penaltyKillPct': 0.787879,
#   'pointPct': 0.71428,
#   'points': 30,
#   'powerPlayNetPct': 0.101694,
#   'powerPlayPct': 0.135593,
#   'regulationAndOtWins': 13,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 25.85714,
#   'shotsForPerGame': 33.85714,
#   'teamFullName': 'Carolina Hurricanes',
#   'teamId': 12,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 14,
#   'winsInRegulation': 10,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.52931,
#   'gamesPlayed': 21,
#   'goalsAgainst': 58,
#   'goalsAgainstPerGame': 2.7619,
#   'goalsFor': 68,
#   'goalsForPerGame': 3.23809,
#   'losses': 5,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.765625,
#   'penaltyKillPct': 0.765625,
#   'pointPct': 0.69047,
#   'points': 29,
#   'powerPlayNetPct': 0.253521,
#   'powerPlayPct': 0.309859,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 27.61904,
#   'shotsForPerGame': 25.71428,
#   'teamFullName': 'Dallas Stars',
#   'teamId': 25,
#   'teamShutouts': 2,
#   'ties': None,
#   'wins': 13,
#   'winsInRegulation': 10,
#   'winsInShootout': 2},
#  {'faceoffWinPct': 0.495689,
#   'gamesPlayed': 21,
#   'goalsAgainst': 64,
#   'goalsAgainstPerGame': 3.04761,
#   'goalsFor': 63,
#   'goalsForPerGame': 3.0,
#   'losses': 7,
#   'otLosses': 1,
#   'penaltyKillNetPct': 0.901639,
#   'penaltyKillPct': 0.836066,
#   'pointPct': 0.64285,
#   'points': 27,
#   'powerPlayNetPct': 0.236363,
#   'powerPlayPct': 0.236363,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 27.85714,
#   'shotsForPerGame': 30.0,
#   'teamFullName': 'New Jersey Devils',
#   'teamId': 1,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 13,
#   'winsInRegulation': 8,
#   'winsInShootout': 2},
#  {'faceoffWinPct': 0.522957,
#   'gamesPlayed': 22,
#   'goalsAgainst': 70,
#   'goalsAgainstPerGame': 3.18181,
#   'goalsFor': 64,
#   'goalsForPerGame': 2.90909,
#   'losses': 8,
#   'otLosses': 1,
#   'penaltyKillNetPct': 0.809523,
#   'penaltyKillPct': 0.809524,
#   'pointPct': 0.61363,
#   'points': 27,
#   'powerPlayNetPct': 0.166666,
#   'powerPlayPct': 0.208333,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 26.72727,
#   'shotsForPerGame': 29.95454,
#   'teamFullName': 'Detroit Red Wings',
#   'teamId': 17,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 13,
#   'winsInRegulation': 9,
#   'winsInShootout': 2},
#  {'faceoffWinPct': 0.466393,
#   'gamesPlayed': 21,
#   'goalsAgainst': 66,
#   'goalsAgainstPerGame': 3.14285,
#   'goalsFor': 75,
#   'goalsForPerGame': 3.57142,
#   'losses': 7,
#   'otLosses': 1,
#   'penaltyKillNetPct': 0.791666,
#   'penaltyKillPct': 0.75,
#   'pointPct': 0.64285,
#   'points': 27,
#   'powerPlayNetPct': 0.208333,
#   'powerPlayPct': 0.208333,
#   'regulationAndOtWins': 12,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 30.04761,
#   'shotsForPerGame': 29.90476,
#   'teamFullName': 'Anaheim Ducks',
#   'teamId': 24,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 13,
#   'winsInRegulation': 9,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.45098,
#   'gamesPlayed': 21,
#   'goalsAgainst': 56,
#   'goalsAgainstPerGame': 2.66666,
#   'goalsFor': 57,
#   'goalsForPerGame': 2.71428,
#   'losses': 5,
#   'otLosses': 5,
#   'penaltyKillNetPct': 0.716666,
#   'penaltyKillPct': 0.7,
#   'pointPct': 0.64285,
#   'points': 27,
#   'powerPlayNetPct': 0.183333,
#   'powerPlayPct': 0.2,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 27.5238,
#   'shotsForPerGame': 24.38095,
#   'teamFullName': 'Seattle Kraken',
#   'teamId': 55,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 7,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.526162,
#   'gamesPlayed': 23,
#   'goalsAgainst': 74,
#   'goalsAgainstPerGame': 3.21739,
#   'goalsFor': 73,
#   'goalsForPerGame': 3.17391,
#   'losses': 10,
#   'otLosses': 0,
#   'penaltyKillNetPct': 0.829545,
#   'penaltyKillPct': 0.829546,
#   'pointPct': 0.56521,
#   'points': 26,
#   'powerPlayNetPct': 0.213333,
#   'powerPlayPct': 0.266666,
#   'regulationAndOtWins': 12,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 29.91304,
#   'shotsForPerGame': 27.43478,
#   'teamFullName': 'Boston Bruins',
#   'teamId': 6,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 13,
#   'winsInRegulation': 8,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.519902,
#   'gamesPlayed': 22,
#   'goalsAgainst': 64,
#   'goalsAgainstPerGame': 2.90909,
#   'goalsFor': 70,
#   'goalsForPerGame': 3.18181,
#   'losses': 8,
#   'otLosses': 2,
#   'penaltyKillNetPct': 0.9,
#   'penaltyKillPct': 0.828572,
#   'pointPct': 0.5909,
#   'points': 26,
#   'powerPlayNetPct': 0.109589,
#   'powerPlayPct': 0.136986,
#   'regulationAndOtWins': 12,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 28.5,
#   'shotsForPerGame': 28.5,
#   'teamFullName': 'New York Islanders',
#   'teamId': 2,
#   'teamShutouts': 2,
#   'ties': None,
#   'wins': 12,
#   'winsInRegulation': 9,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.451077,
#   'gamesPlayed': 21,
#   'goalsAgainst': 60,
#   'goalsAgainstPerGame': 2.85714,
#   'goalsFor': 66,
#   'goalsForPerGame': 3.14285,
#   'losses': 7,
#   'otLosses': 2,
#   'penaltyKillNetPct': 0.901408,
#   'penaltyKillPct': 0.87324,
#   'pointPct': 0.61904,
#   'points': 26,
#   'powerPlayNetPct': 0.161764,
#   'powerPlayPct': 0.17647,
#   'regulationAndOtWins': 12,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 27.90476,
#   'shotsForPerGame': 26.66666,
#   'teamFullName': 'Tampa Bay Lightning',
#   'teamId': 14,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 12,
#   'winsInRegulation': 9,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.581572,
#   'gamesPlayed': 21,
#   'goalsAgainst': 69,
#   'goalsAgainstPerGame': 3.28571,
#   'goalsFor': 68,
#   'goalsForPerGame': 3.23809,
#   'losses': 6,
#   'otLosses': 4,
#   'penaltyKillNetPct': 0.716666,
#   'penaltyKillPct': 0.7,
#   'pointPct': 0.61904,
#   'points': 26,
#   'powerPlayNetPct': 0.205882,
#   'powerPlayPct': 0.235294,
#   'regulationAndOtWins': 9,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 25.04761,
#   'shotsForPerGame': 26.5238,
#   'teamFullName': 'Ottawa Senators',
#   'teamId': 9,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 8,
#   'winsInShootout': 2},
#  {'faceoffWinPct': 0.480407,
#   'gamesPlayed': 22,
#   'goalsAgainst': 64,
#   'goalsAgainstPerGame': 2.90909,
#   'goalsFor': 63,
#   'goalsForPerGame': 2.86363,
#   'losses': 7,
#   'otLosses': 4,
#   'penaltyKillNetPct': 0.76,
#   'penaltyKillPct': 0.74,
#   'pointPct': 0.5909,
#   'points': 26,
#   'powerPlayNetPct': 0.259259,
#   'powerPlayPct': 0.259259,
#   'regulationAndOtWins': 9,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 29.54545,
#   'shotsForPerGame': 27.77272,
#   'teamFullName': 'Minnesota Wild',
#   'teamId': 30,
#   'teamShutouts': 4,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 7,
#   'winsInShootout': 2},
#  {'faceoffWinPct': 0.495603,
#   'gamesPlayed': 22,
#   'goalsAgainst': 59,
#   'goalsAgainstPerGame': 2.68181,
#   'goalsFor': 59,
#   'goalsForPerGame': 2.68181,
#   'losses': 6,
#   'otLosses': 6,
#   'penaltyKillNetPct': 0.875,
#   'penaltyKillPct': 0.805556,
#   'pointPct': 0.5909,
#   'points': 26,
#   'powerPlayNetPct': 0.085714,
#   'powerPlayPct': 0.142857,
#   'regulationAndOtWins': 9,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 26.0,
#   'shotsForPerGame': 29.36363,
#   'teamFullName': 'Los Angeles Kings',
#   'teamId': 26,
#   'teamShutouts': 2,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 6,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.535379,
#   'gamesPlayed': 20,
#   'goalsAgainst': 55,
#   'goalsAgainstPerGame': 2.75,
#   'goalsFor': 64,
#   'goalsForPerGame': 3.2,
#   'losses': 4,
#   'otLosses': 6,
#   'penaltyKillNetPct': 0.814814,
#   'penaltyKillPct': 0.796297,
#   'pointPct': 0.65,
#   'points': 26,
#   'powerPlayNetPct': 0.214285,
#   'powerPlayPct': 0.242857,
#   'regulationAndOtWins': 10,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 25.1,
#   'shotsForPerGame': 29.6,
#   'teamFullName': 'Vegas Golden Knights',
#   'teamId': 54,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 9,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.477231,
#   'gamesPlayed': 20,
#   'goalsAgainst': 56,
#   'goalsAgainstPerGame': 2.8,
#   'goalsFor': 56,
#   'goalsForPerGame': 2.8,
#   'losses': 6,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.85,
#   'penaltyKillPct': 0.85,
#   'pointPct': 0.625,
#   'points': 25,
#   'powerPlayNetPct': 0.14035,
#   'powerPlayPct': 0.175438,
#   'regulationAndOtWins': 7,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 25.85,
#   'shotsForPerGame': 25.1,
#   'teamFullName': 'Philadelphia Flyers',
#   'teamId': 4,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 5,
#   'winsInShootout': 4},
#  {'faceoffWinPct': 0.508912,
#   'gamesPlayed': 21,
#   'goalsAgainst': 74,
#   'goalsAgainstPerGame': 3.5238,
#   'goalsFor': 72,
#   'goalsForPerGame': 3.42857,
#   'losses': 7,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.791666,
#   'penaltyKillPct': 0.763889,
#   'pointPct': 0.59523,
#   'points': 25,
#   'powerPlayNetPct': 0.209677,
#   'powerPlayPct': 0.209677,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 26.66666,
#   'shotsForPerGame': 25.5238,
#   'teamFullName': 'Montréal Canadiens',
#   'teamId': 8,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 6,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.505426,
#   'gamesPlayed': 22,
#   'goalsAgainst': 70,
#   'goalsAgainstPerGame': 3.18181,
#   'goalsFor': 65,
#   'goalsForPerGame': 2.95454,
#   'losses': 8,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.759259,
#   'penaltyKillPct': 0.740741,
#   'pointPct': 0.56818,
#   'points': 25,
#   'powerPlayNetPct': 0.156862,
#   'powerPlayPct': 0.17647,
#   'regulationAndOtWins': 8,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 31.40909,
#   'shotsForPerGame': 30.68181,
#   'teamFullName': 'Columbus Blue Jackets',
#   'teamId': 29,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 6,
#   'winsInShootout': 3},
#  {'faceoffWinPct': 0.497741,
#   'gamesPlayed': 21,
#   'goalsAgainst': 55,
#   'goalsAgainstPerGame': 2.61904,
#   'goalsFor': 64,
#   'goalsForPerGame': 3.04761,
#   'losses': 6,
#   'otLosses': 5,
#   'penaltyKillNetPct': 0.868852,
#   'penaltyKillPct': 0.85246,
#   'pointPct': 0.59523,
#   'points': 25,
#   'powerPlayNetPct': 0.28,
#   'powerPlayPct': 0.32,
#   'regulationAndOtWins': 10,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 28.38095,
#   'shotsForPerGame': 27.19047,
#   'teamFullName': 'Pittsburgh Penguins',
#   'teamId': 5,
#   'teamShutouts': 3,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 10,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.530373,
#   'gamesPlayed': 24,
#   'goalsAgainst': 85,
#   'goalsAgainstPerGame': 3.54166,
#   'goalsFor': 74,
#   'goalsForPerGame': 3.08333,
#   'losses': 9,
#   'otLosses': 5,
#   'penaltyKillNetPct': 0.854838,
#   'penaltyKillPct': 0.822581,
#   'pointPct': 0.52083,
#   'points': 25,
#   'powerPlayNetPct': 0.237288,
#   'powerPlayPct': 0.288135,
#   'regulationAndOtWins': 10,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 26.45833,
#   'shotsForPerGame': 28.45833,
#   'teamFullName': 'Edmonton Oilers',
#   'teamId': 22,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 5,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.528933,
#   'gamesPlayed': 20,
#   'goalsAgainst': 56,
#   'goalsAgainstPerGame': 2.8,
#   'goalsFor': 66,
#   'goalsForPerGame': 3.3,
#   'losses': 8,
#   'otLosses': 0,
#   'penaltyKillNetPct': 0.876712,
#   'penaltyKillPct': 0.835617,
#   'pointPct': 0.6,
#   'points': 24,
#   'powerPlayNetPct': 0.238095,
#   'powerPlayPct': 0.253968,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 28.85,
#   'shotsForPerGame': 27.05,
#   'teamFullName': 'Winnipeg Jets',
#   'teamId': 52,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 12,
#   'winsInRegulation': 10,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.481856,
#   'gamesPlayed': 22,
#   'goalsAgainst': 60,
#   'goalsAgainstPerGame': 2.72727,
#   'goalsFor': 71,
#   'goalsForPerGame': 3.22727,
#   'losses': 9,
#   'otLosses': 2,
#   'penaltyKillNetPct': 0.718309,
#   'penaltyKillPct': 0.71831,
#   'pointPct': 0.54545,
#   'points': 24,
#   'powerPlayNetPct': 0.102941,
#   'powerPlayPct': 0.147058,
#   'regulationAndOtWins': 11,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 26.0909,
#   'shotsForPerGame': 29.72727,
#   'teamFullName': 'Washington Capitals',
#   'teamId': 15,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 10,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.46321,
#   'gamesPlayed': 21,
#   'goalsAgainst': 60,
#   'goalsAgainstPerGame': 2.85714,
#   'goalsFor': 69,
#   'goalsForPerGame': 3.28571,
#   'losses': 7,
#   'otLosses': 4,
#   'penaltyKillNetPct': 0.84,
#   'penaltyKillPct': 0.826667,
#   'pointPct': 0.57142,
#   'points': 24,
#   'powerPlayNetPct': 0.233333,
#   'powerPlayPct': 0.25,
#   'regulationAndOtWins': 10,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 31.04761,
#   'shotsForPerGame': 25.0,
#   'teamFullName': 'Chicago Blackhawks',
#   'teamId': 16,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 9,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.480991,
#   'gamesPlayed': 21,
#   'goalsAgainst': 64,
#   'goalsAgainstPerGame': 3.04761,
#   'goalsFor': 61,
#   'goalsForPerGame': 2.90476,
#   'losses': 9,
#   'otLosses': 1,
#   'penaltyKillNetPct': 0.821917,
#   'penaltyKillPct': 0.794521,
#   'pointPct': 0.54761,
#   'points': 23,
#   'powerPlayNetPct': 0.19753,
#   'powerPlayPct': 0.209876,
#   'regulationAndOtWins': 10,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 25.38095,
#   'shotsForPerGame': 28.7619,
#   'teamFullName': 'Florida Panthers',
#   'teamId': 13,
#   'teamShutouts': 2,
#   'ties': None,
#   'wins': 11,
#   'winsInRegulation': 10,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.480235,
#   'gamesPlayed': 22,
#   'goalsAgainst': 70,
#   'goalsAgainstPerGame': 3.18181,
#   'goalsFor': 64,
#   'goalsForPerGame': 2.90909,
#   'losses': 9,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.821917,
#   'penaltyKillPct': 0.794521,
#   'pointPct': 0.52272,
#   'points': 23,
#   'powerPlayNetPct': 0.142857,
#   'powerPlayPct': 0.181818,
#   'regulationAndOtWins': 9,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 31.27272,
#   'shotsForPerGame': 23.90909,
#   'teamFullName': 'San Jose Sharks',
#   'teamId': 28,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 4,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.472245,
#   'gamesPlayed': 21,
#   'goalsAgainst': 65,
#   'goalsAgainstPerGame': 3.09523,
#   'goalsFor': 63,
#   'goalsForPerGame': 3.0,
#   'losses': 8,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.827586,
#   'penaltyKillPct': 0.827587,
#   'pointPct': 0.54761,
#   'points': 23,
#   'powerPlayNetPct': 0.145161,
#   'powerPlayPct': 0.145161,
#   'regulationAndOtWins': 10,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 24.04761,
#   'shotsForPerGame': 28.80952,
#   'teamFullName': 'Utah Mammoth',
#   'teamId': 68,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 7,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.531561,
#   'gamesPlayed': 22,
#   'goalsAgainst': 58,
#   'goalsAgainstPerGame': 2.63636,
#   'goalsFor': 55,
#   'goalsForPerGame': 2.5,
#   'losses': 10,
#   'otLosses': 2,
#   'penaltyKillNetPct': 0.8125,
#   'penaltyKillPct': 0.78125,
#   'pointPct': 0.5,
#   'points': 22,
#   'powerPlayNetPct': 0.169811,
#   'powerPlayPct': 0.207547,
#   'regulationAndOtWins': 9,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 28.31818,
#   'shotsForPerGame': 26.72727,
#   'teamFullName': 'New York Rangers',
#   'teamId': 3,
#   'teamShutouts': 2,
#   'ties': None,
#   'wins': 10,
#   'winsInRegulation': 7,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.562255,
#   'gamesPlayed': 22,
#   'goalsAgainst': 82,
#   'goalsAgainstPerGame': 3.72727,
#   'goalsFor': 74,
#   'goalsForPerGame': 3.36363,
#   'losses': 10,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.815384,
#   'penaltyKillPct': 0.8,
#   'pointPct': 0.47727,
#   'points': 21,
#   'powerPlayNetPct': 0.120689,
#   'powerPlayPct': 0.155172,
#   'regulationAndOtWins': 9,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 30.95454,
#   'shotsForPerGame': 27.77272,
#   'teamFullName': 'Toronto Maple Leafs',
#   'teamId': 10,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 9,
#   'winsInRegulation': 6,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.473429,
#   'gamesPlayed': 22,
#   'goalsAgainst': 81,
#   'goalsAgainstPerGame': 3.68181,
#   'goalsFor': 67,
#   'goalsForPerGame': 3.04545,
#   'losses': 11,
#   'otLosses': 2,
#   'penaltyKillNetPct': 0.722222,
#   'penaltyKillPct': 0.680556,
#   'pointPct': 0.45454,
#   'points': 20,
#   'powerPlayNetPct': 0.205479,
#   'powerPlayPct': 0.232876,
#   'regulationAndOtWins': 7,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 30.72727,
#   'shotsForPerGame': 26.45454,
#   'teamFullName': 'Vancouver Canucks',
#   'teamId': 23,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 9,
#   'winsInRegulation': 5,
#   'winsInShootout': 2},
#  {'faceoffWinPct': 0.433281,
#   'gamesPlayed': 21,
#   'goalsAgainst': 74,
#   'goalsAgainstPerGame': 3.5238,
#   'goalsFor': 66,
#   'goalsForPerGame': 3.14285,
#   'losses': 9,
#   'otLosses': 4,
#   'penaltyKillNetPct': 0.934426,
#   'penaltyKillPct': 0.885246,
#   'pointPct': 0.47619,
#   'points': 20,
#   'powerPlayNetPct': 0.15873,
#   'powerPlayPct': 0.174603,
#   'regulationAndOtWins': 7,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 31.5238,
#   'shotsForPerGame': 28.04761,
#   'teamFullName': 'Buffalo Sabres',
#   'teamId': 7,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 8,
#   'winsInRegulation': 6,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.509122,
#   'gamesPlayed': 22,
#   'goalsAgainst': 80,
#   'goalsAgainstPerGame': 3.63636,
#   'goalsFor': 59,
#   'goalsForPerGame': 2.68181,
#   'losses': 9,
#   'otLosses': 6,
#   'penaltyKillNetPct': 0.785714,
#   'penaltyKillPct': 0.75,
#   'pointPct': 0.45454,
#   'points': 20,
#   'powerPlayNetPct': 0.222222,
#   'powerPlayPct': 0.24074,
#   'regulationAndOtWins': 7,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 28.0,
#   'shotsForPerGame': 25.72727,
#   'teamFullName': 'St. Louis Blues',
#   'teamId': 19,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 7,
#   'winsInRegulation': 7,
#   'winsInShootout': 0},
#  {'faceoffWinPct': 0.525061,
#   'gamesPlayed': 21,
#   'goalsAgainst': 73,
#   'goalsAgainstPerGame': 3.47619,
#   'goalsFor': 48,
#   'goalsForPerGame': 2.28571,
#   'losses': 11,
#   'otLosses': 4,
#   'penaltyKillNetPct': 0.836065,
#   'penaltyKillPct': 0.819673,
#   'pointPct': 0.38095,
#   'points': 16,
#   'powerPlayNetPct': 0.153846,
#   'powerPlayPct': 0.153846,
#   'regulationAndOtWins': 5,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 27.33333,
#   'shotsForPerGame': 27.38095,
#   'teamFullName': 'Nashville Predators',
#   'teamId': 18,
#   'teamShutouts': 0,
#   'ties': None,
#   'wins': 6,
#   'winsInRegulation': 4,
#   'winsInShootout': 1},
#  {'faceoffWinPct': 0.489906,
#   'gamesPlayed': 22,
#   'goalsAgainst': 67,
#   'goalsAgainstPerGame': 3.04545,
#   'goalsFor': 50,
#   'goalsForPerGame': 2.27272,
#   'losses': 13,
#   'otLosses': 3,
#   'penaltyKillNetPct': 0.808219,
#   'penaltyKillPct': 0.794521,
#   'pointPct': 0.3409,
#   'points': 15,
#   'powerPlayNetPct': 0.097222,
#   'powerPlayPct': 0.125,
#   'regulationAndOtWins': 5,
#   'seasonId': 20252026,
#   'shotsAgainstPerGame': 28.5,
#   'shotsForPerGame': 29.68181,
#   'teamFullName': 'Calgary Flames',
#   'teamId': 20,
#   'teamShutouts': 1,
#   'ties': None,
#   'wins': 6,
#   'winsInRegulation': 5,
#   'winsInShootout': 1}]

# %%
client.schedule.daily_schedule("2025-11-21")
# Out:
# {'nextStartDate': '2025-11-28',
#  'previousStartDate': '2025-11-14',
#  'date': '2025-11-21',
#  'oddsPartners': [{'partnerId': 2,
#    'country': 'SE',
#    'name': 'Unibet',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/unibet.svg',
#    'siteUrl': 'https://www.unibet.se/betting/sports/filter/ice_hockey/nhl/all/matches',
#    'bgColor': '#14805E',
#    'textColor': '#FFFFFF',
#    'accentColor': '#3AAA35'},
#   {'partnerId': 3,
#    'country': 'CZ',
#    'name': 'Tipsport',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/tipsport.svg',
#    'siteUrl': 'https://www.tipsport.cz/PartnerRedirectAction.do?pid=16961&sid=20360&bid=34954&tid=11268',
#    'bgColor': '#2497F2',
#    'textColor': '#FFFFFF',
#    'accentColor': '#FFFFFF'},
#   {'partnerId': 6,
#    'country': 'FI',
#    'name': 'Veikkaus',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/veikkaus.svg',
#    'siteUrl': 'https://www.veikkaus.fi/fi/vedonlyonti/pitkaveto?t=3-2-1_NHL',
#    'bgColor': '#0025F5',
#    'textColor': '#FFFFFF',
#    'accentColor': '#FFFFFF'},
#   {'partnerId': 7,
#    'country': 'CA',
#    'name': 'FanDuel',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/fanduel.svg',
#    'siteUrl': 'https://fanduel.com',
#    'bgColor': '#0078ff',
#    'textColor': '#FFFFFF',
#    'accentColor': '#FFFFFF'},
#   {'partnerId': 8,
#    'country': 'DE',
#    'name': 'Sportradar',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/sportsradar.svg',
#    'siteUrl': 'https://sportradar.com',
#    'bgColor': '#000000',
#    'textColor': '#FFFFFF',
#    'accentColor': '#E6E6E6'},
#   {'partnerId': 9,
#    'country': 'US',
#    'name': 'DraftKings',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/draftkings.svg',
#    'siteUrl': '',
#    'bgColor': '#000000',
#    'textColor': '#FFFFFF',
#    'accentColor': '#FFFFFF'},
#   {'partnerId': 10,
#    'country': 'SK',
#    'name': 'Doxxbet',
#    'imageUrl': 'https://assets.nhle.com/betting_partner/doxxbet.svg',
#    'siteUrl': 'https://www.doxxbet.sk/sk/sportove-tipovanie-online/kurzy/ladovy-hokej/usa/nhl/?msID=21&mbID=27',
#    'bgColor': '#f30d31',
#    'textColor': '#202020',
#    'accentColor': '#ffffff'}],
#  'games': [{'id': 2025020331,
#    'season': 20252026,
#    'gameType': 2,
#    'venue': {'default': 'KeyBank Center'},
#    'neutralSite': False,
#    'startTimeUTC': '2025-11-22T00:00:00Z',
#    'easternUTCOffset': '-05:00',
#    'venueUTCOffset': '-05:00',
#    'venueTimezone': 'America/New_York',
#    'gameState': 'OFF',
#    'gameScheduleState': 'OK',
#    'tvBroadcasts': [{'id': 282,
#      'market': 'N',
#      'countryCode': 'CA',
#      'network': 'SN',
#      'sequenceNumber': 101},
#     {'id': 551,
#      'market': 'A',
#      'countryCode': 'US',
#      'network': 'CHSN',
#      'sequenceNumber': 243},
#     {'id': 28,
#      'market': 'H',
#      'countryCode': 'US',
#      'network': 'MSG-B',
#      'sequenceNumber': 383}],
#    'awayTeam': {'id': 16,
#     'commonName': {'default': 'Blackhawks'},
#     'placeName': {'default': 'Chicago'},
#     'placeNameWithPreposition': {'default': 'Chicago', 'fr': 'de Chicago'},
#     'abbrev': 'CHI',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/CHI_light.svg?season=20252026',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CHI_dark.svg?season=20252026',
#     'awaySplitSquad': False,
#     'score': 3},
#    'homeTeam': {'id': 7,
#     'commonName': {'default': 'Sabres'},
#     'placeName': {'default': 'Buffalo'},
#     'placeNameWithPreposition': {'default': 'Buffalo', 'fr': 'de Buffalo'},
#     'abbrev': 'BUF',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/BUF_light.svg',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/BUF_dark.svg',
#     'homeSplitSquad': False,
#     'score': 9},
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'gameOutcome': {'lastPeriodType': 'REG'},
#    'winningGoalie': {'playerId': 8480045,
#     'firstInitial': {'default': 'U.'},
#     'lastName': {'default': 'Luukkonen'}},
#    'winningGoalScorer': {'playerId': 8480802,
#     'firstInitial': {'default': 'R.'},
#     'lastName': {'default': 'McLeod'}},
#    'threeMinRecap': '/video/chi-at-buf-recap-6385435015112',
#    'threeMinRecapFr': '/fr/video/chi-vs-buf-21-11-2025-resume-6385436054112',
#    'condensedGame': '/video/chi-at-buf-condensed-game-6385435986112',
#    'condensedGameFr': '/fr/video/match-condense-blackhawks-sabres-21-11-2025-6385436055112',
#    'gameCenterLink': '/gamecenter/chi-vs-buf/2025/11/21/2025020331'},
#   {'id': 2025020332,
#    'season': 20252026,
#    'gameType': 2,
#    'venue': {'default': 'PPG Paints Arena'},
#    'neutralSite': False,
#    'startTimeUTC': '2025-11-22T00:00:00Z',
#    'easternUTCOffset': '-05:00',
#    'venueUTCOffset': '-05:00',
#    'venueTimezone': 'US/Eastern',
#    'gameState': 'OFF',
#    'gameScheduleState': 'OK',
#    'tvBroadcasts': [{'id': 324,
#      'market': 'N',
#      'countryCode': 'US',
#      'network': 'NHLN',
#      'sequenceNumber': 35},
#     {'id': 281,
#      'market': 'N',
#      'countryCode': 'CA',
#      'network': 'TVAS',
#      'sequenceNumber': 109},
#     {'id': 567,
#      'market': 'A',
#      'countryCode': 'US',
#      'network': 'FDSNNO',
#      'sequenceNumber': 274},
#     {'id': 528,
#      'market': 'H',
#      'countryCode': 'US',
#      'network': 'SN-PIT',
#      'sequenceNumber': 375},
#     {'id': 569,
#      'market': 'A',
#      'countryCode': 'US',
#      'network': 'FDSNWI',
#      'sequenceNumber': 410}],
#    'awayTeam': {'id': 30,
#     'commonName': {'default': 'Wild'},
#     'placeName': {'default': 'Minnesota'},
#     'placeNameWithPreposition': {'default': 'Minnesota', 'fr': 'du Minnesota'},
#     'abbrev': 'MIN',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/MIN_light.svg',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/MIN_dark.svg',
#     'awaySplitSquad': False,
#     'score': 5},
#    'homeTeam': {'id': 5,
#     'commonName': {'default': 'Penguins'},
#     'placeName': {'default': 'Pittsburgh'},
#     'placeNameWithPreposition': {'default': 'Pittsburgh',
#      'fr': 'de Pittsburgh'},
#     'abbrev': 'PIT',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/PIT_light.svg',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/PIT_dark.svg',
#     'homeSplitSquad': False,
#     'score': 0},
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'gameOutcome': {'lastPeriodType': 'REG'},
#    'winningGoalie': {'playerId': 8479406,
#     'firstInitial': {'default': 'F.'},
#     'lastName': {'default': 'Gustavsson'}},
#    'winningGoalScorer': {'playerId': 8481557,
#     'firstInitial': {'default': 'M.'},
#     'lastName': {'default': 'Boldy'}},
#    'threeMinRecap': '/video/min-at-pit-recap-6385436060112',
#    'threeMinRecapFr': '/fr/video/min-vs-pit-21-11-2025-resume-6385436451112',
#    'condensedGame': '/video/min-at-pit-condensed-game-6385435700112',
#    'condensedGameFr': '/fr/video/match-condense-wild-penguins-21-11-2025-6385435480112',
#    'gameCenterLink': '/gamecenter/min-vs-pit/2025/11/21/2025020332'},
#   {'id': 2025020333,
#    'season': 20252026,
#    'gameType': 2,
#    'venue': {'default': 'Canada Life Centre'},
#    'neutralSite': False,
#    'startTimeUTC': '2025-11-22T01:00:00Z',
#    'easternUTCOffset': '-05:00',
#    'venueUTCOffset': '-06:00',
#    'venueTimezone': 'America/Winnipeg',
#    'gameState': 'OFF',
#    'gameScheduleState': 'OK',
#    'tvBroadcasts': [{'id': 292,
#      'market': 'H',
#      'countryCode': 'CA',
#      'network': 'TSN3',
#      'sequenceNumber': 134},
#     {'id': 561,
#      'market': 'A',
#      'countryCode': 'US',
#      'network': 'FDSNSO',
#      'sequenceNumber': 277}],
#    'awayTeam': {'id': 12,
#     'commonName': {'default': 'Hurricanes'},
#     'placeName': {'default': 'Carolina', 'fr': 'Caroline'},
#     'placeNameWithPreposition': {'default': 'Carolina',
#      'fr': 'de la Caroline'},
#     'abbrev': 'CAR',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/CAR_light.svg',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CAR_dark.svg',
#     'awaySplitSquad': False,
#     'score': 4},
#    'homeTeam': {'id': 52,
#     'commonName': {'default': 'Jets'},
#     'placeName': {'default': 'Winnipeg'},
#     'placeNameWithPreposition': {'default': 'Winnipeg', 'fr': 'de Winnipeg'},
#     'abbrev': 'WPG',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/WPG_dark.svg',
#     'homeSplitSquad': False,
#     'score': 3},
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'gameOutcome': {'lastPeriodType': 'REG'},
#    'winningGoalie': {'playerId': 8483548,
#     'firstInitial': {'default': 'B.'},
#     'lastName': {'default': 'Bussi'}},
#    'winningGoalScorer': {'playerId': 8480830,
#     'firstInitial': {'default': 'A.'},
#     'lastName': {'default': 'Svechnikov',
#      'cs': 'Svečnikov',
#      'fi': 'Svetshnikov',
#      'sk': 'Svečnikov'}},
#    'threeMinRecap': '/video/car-at-wpg-recap-6385438285112',
#    'threeMinRecapFr': '/fr/video/car-vs-wpg-21-11-2025-resume-6385437915112',
#    'condensedGame': '/video/car-at-wpg-condensed-game-6385438286112',
#    'condensedGameFr': '/fr/video/match-condense-hurricanes-jets-21-11-2025-6385438009112',
#    'gameCenterLink': '/gamecenter/car-vs-wpg/2025/11/21/2025020333'},
#   {'id': 2025020334,
#    'season': 20252026,
#    'gameType': 2,
#    'venue': {'default': 'Crypto.com Arena'},
#    'neutralSite': False,
#    'startTimeUTC': '2025-11-22T03:30:00Z',
#    'easternUTCOffset': '-05:00',
#    'venueUTCOffset': '-08:00',
#    'venueTimezone': 'America/Los_Angeles',
#    'gameState': 'OFF',
#    'gameScheduleState': 'OK',
#    'tvBroadcasts': [{'id': 282,
#      'market': 'N',
#      'countryCode': 'CA',
#      'network': 'SN',
#      'sequenceNumber': 101},
#     {'id': 564,
#      'market': 'H',
#      'countryCode': 'US',
#      'network': 'FDSNW',
#      'sequenceNumber': 279},
#     {'id': 31,
#      'market': 'A',
#      'countryCode': 'US',
#      'network': 'NESN',
#      'sequenceNumber': 396}],
#    'awayTeam': {'id': 6,
#     'commonName': {'default': 'Bruins'},
#     'placeName': {'default': 'Boston'},
#     'placeNameWithPreposition': {'default': 'Boston', 'fr': 'de Boston'},
#     'abbrev': 'BOS',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/BOS_light.svg?season=20252026',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/BOS_dark.svg?season=20252026',
#     'awaySplitSquad': False,
#     'score': 2},
#    'homeTeam': {'id': 26,
#     'commonName': {'default': 'Kings'},
#     'placeName': {'default': 'Los Angeles'},
#     'placeNameWithPreposition': {'default': 'Los Angeles',
#      'fr': 'de Los Angeles'},
#     'abbrev': 'LAK',
#     'logo': 'https://assets.nhle.com/logos/nhl/svg/LAK_light.svg',
#     'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/LAK_dark.svg',
#     'homeSplitSquad': False,
#     'score': 1},
#    'periodDescriptor': {'number': 4,
#     'periodType': 'OT',
#     'maxRegulationPeriods': 3},
#    'gameOutcome': {'lastPeriodType': 'OT'},
#    'winningGoalie': {'playerId': 8480280,
#     'firstInitial': {'default': 'J.'},
#     'lastName': {'default': 'Swayman'}},
#    'winningGoalScorer': {'playerId': 8479987,
#     'firstInitial': {'default': 'M.'},
#     'lastName': {'default': 'Geekie'}},
#    'threeMinRecap': '/video/bos-at-lak-recap-6385443192112',
#    'threeMinRecapFr': '/fr/video/bos-vs-lak-21-11-2025-resume-6385442902112',
#    'condensedGame': '/video/bos-at-lak-condensed-game-6385445039112',
#    'condensedGameFr': '/fr/video/match-condense-bruins-kings-21-11-2025-6385444943112',
#    'gameCenterLink': '/gamecenter/bos-vs-lak/2025/11/21/2025020334'}],
#  'numberOfGames': 4}

# %%
client.teams.teams()
# Out:
# [{'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Colorado Avalanche',
#   'common_name': 'Avalanche',
#   'abbr': 'COL',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/COL_light.svg',
#   'franchise_id': 27},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'Carolina Hurricanes',
#   'common_name': 'Hurricanes',
#   'abbr': 'CAR',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CAR_light.svg',
#   'franchise_id': 26},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Dallas Stars',
#   'common_name': 'Stars',
#   'abbr': 'DAL',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/DAL_light.svg',
#   'franchise_id': 15},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Anaheim Ducks',
#   'common_name': 'Ducks',
#   'abbr': 'ANA',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/ANA_light.svg',
#   'franchise_id': 32},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'New Jersey Devils',
#   'common_name': 'Devils',
#   'abbr': 'NJD',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/NJD_light.svg',
#   'franchise_id': 23},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Seattle Kraken',
#   'common_name': 'Kraken',
#   'abbr': 'SEA',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/SEA_light.svg',
#   'franchise_id': 39},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Detroit Red Wings',
#   'common_name': 'Red Wings',
#   'abbr': 'DET',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/DET_light.svg?season=20252026',
#   'franchise_id': 12},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Vegas Golden Knights',
#   'common_name': 'Golden Knights',
#   'abbr': 'VGK',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/VGK_light.svg',
#   'franchise_id': 38},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Tampa Bay Lightning',
#   'common_name': 'Lightning',
#   'abbr': 'TBL',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/TBL_light.svg',
#   'franchise_id': 31},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Ottawa Senators',
#   'common_name': 'Senators',
#   'abbr': 'OTT',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/OTT_light.svg',
#   'franchise_id': 30},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'New York Islanders',
#   'common_name': 'Islanders',
#   'abbr': 'NYI',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/NYI_light.svg',
#   'franchise_id': 22},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Minnesota Wild',
#   'common_name': 'Wild',
#   'abbr': 'MIN',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/MIN_light.svg',
#   'franchise_id': 37},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Los Angeles Kings',
#   'common_name': 'Kings',
#   'abbr': 'LAK',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/LAK_light.svg',
#   'franchise_id': 14},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Boston Bruins',
#   'common_name': 'Bruins',
#   'abbr': 'BOS',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/BOS_light.svg?season=20252026',
#   'franchise_id': 6},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'Philadelphia Flyers',
#   'common_name': 'Flyers',
#   'abbr': 'PHI',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/PHI_light.svg',
#   'franchise_id': 16},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'Pittsburgh Penguins',
#   'common_name': 'Penguins',
#   'abbr': 'PIT',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/PIT_light.svg',
#   'franchise_id': 17},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Montréal Canadiens',
#   'common_name': 'Canadiens',
#   'abbr': 'MTL',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/MTL_light.svg',
#   'franchise_id': 1},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'Columbus Blue Jackets',
#   'common_name': 'Blue Jackets',
#   'abbr': 'CBJ',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CBJ_light.svg',
#   'franchise_id': 36},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Edmonton Oilers',
#   'common_name': 'Oilers',
#   'abbr': 'EDM',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/EDM_light.svg',
#   'franchise_id': 25},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Winnipeg Jets',
#   'common_name': 'Jets',
#   'abbr': 'WPG',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/WPG_light.svg',
#   'franchise_id': 35},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Chicago Blackhawks',
#   'common_name': 'Blackhawks',
#   'abbr': 'CHI',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CHI_light.svg?season=20252026',
#   'franchise_id': 11},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'Washington Capitals',
#   'common_name': 'Capitals',
#   'abbr': 'WSH',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/WSH_secondary_light.svg',
#   'franchise_id': 24},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Florida Panthers',
#   'common_name': 'Panthers',
#   'abbr': 'FLA',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/FLA_light.svg',
#   'franchise_id': 33},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Utah Mammoth',
#   'common_name': 'Mammoth',
#   'abbr': 'UTA',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/UTA_light.svg?season=20252026',
#   'franchise_id': 40},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'San Jose Sharks',
#   'common_name': 'Sharks',
#   'abbr': 'SJS',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/SJS_light.svg',
#   'franchise_id': 29},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'M', 'name': 'Metropolitan'},
#   'name': 'New York Rangers',
#   'common_name': 'Rangers',
#   'abbr': 'NYR',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/NYR_light.svg',
#   'franchise_id': 10},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Toronto Maple Leafs',
#   'common_name': 'Maple Leafs',
#   'abbr': 'TOR',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/TOR_light.svg',
#   'franchise_id': 5},
#  {'conference': {'abbr': 'E', 'name': 'Eastern'},
#   'division': {'abbr': 'A', 'name': 'Atlantic'},
#   'name': 'Buffalo Sabres',
#   'common_name': 'Sabres',
#   'abbr': 'BUF',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/BUF_light.svg',
#   'franchise_id': 19},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'St. Louis Blues',
#   'common_name': 'Blues',
#   'abbr': 'STL',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/STL_light.svg?season=20252026',
#   'franchise_id': 18},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Vancouver Canucks',
#   'common_name': 'Canucks',
#   'abbr': 'VAN',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/VAN_light.svg',
#   'franchise_id': 20},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'C', 'name': 'Central'},
#   'name': 'Nashville Predators',
#   'common_name': 'Predators',
#   'abbr': 'NSH',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/NSH_light.svg',
#   'franchise_id': 34},
#  {'conference': {'abbr': 'W', 'name': 'Western'},
#   'division': {'abbr': 'P', 'name': 'Pacific'},
#   'name': 'Calgary Flames',
#   'common_name': 'Flames',
#   'abbr': 'CGY',
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CGY_light.svg',
#   'franchise_id': 21}]

# %%
client.game_center.play_by_play(2025020331)
# Out:
# {'id': 2025020331,
#  'season': 20252026,
#  'gameType': 2,
#  'limitedScoring': False,
#  'gameDate': '2025-11-21',
#  'venue': {'default': 'KeyBank Center'},
#  'venueLocation': {'default': 'Buffalo'},
#  'startTimeUTC': '2025-11-22T00:00:00Z',
#  'easternUTCOffset': '-05:00',
#  'venueUTCOffset': '-05:00',
#  'tvBroadcasts': [{'id': 282,
#    'market': 'N',
#    'countryCode': 'CA',
#    'network': 'SN',
#    'sequenceNumber': 101},
#   {'id': 551,
#    'market': 'A',
#    'countryCode': 'US',
#    'network': 'CHSN',
#    'sequenceNumber': 243},
#   {'id': 28,
#    'market': 'H',
#    'countryCode': 'US',
#    'network': 'MSG-B',
#    'sequenceNumber': 383}],
#  'gameState': 'OFF',
#  'gameScheduleState': 'OK',
#  'periodDescriptor': {'number': 3,
#   'periodType': 'REG',
#   'maxRegulationPeriods': 3},
#  'awayTeam': {'id': 16,
#   'commonName': {'default': 'Blackhawks'},
#   'abbrev': 'CHI',
#   'score': 3,
#   'sog': 23,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/CHI_light.svg?season=20252026',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/CHI_dark.svg?season=20252026',
#   'placeName': {'default': 'Chicago'},
#   'placeNameWithPreposition': {'default': 'Chicago', 'fr': 'de Chicago'}},
#  'homeTeam': {'id': 7,
#   'commonName': {'default': 'Sabres'},
#   'abbrev': 'BUF',
#   'score': 9,
#   'sog': 30,
#   'logo': 'https://assets.nhle.com/logos/nhl/svg/BUF_light.svg',
#   'darkLogo': 'https://assets.nhle.com/logos/nhl/svg/BUF_dark.svg',
#   'placeName': {'default': 'Buffalo'},
#   'placeNameWithPreposition': {'default': 'Buffalo', 'fr': 'de Buffalo'}},
#  'shootoutInUse': True,
#  'otInUse': True,
#  'clock': {'timeRemaining': '00:00',
#   'secondsRemaining': 0,
#   'running': False,
#   'inIntermission': False},
#  'displayPeriod': 1,
#  'maxPeriods': 5,
#  'gameOutcome': {'lastPeriodType': 'REG'},
#  'plays': [{'eventId': 54,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 520,
#    'typeDescKey': 'period-start',
#    'sortOrder': 9},
#   {'eventId': 53,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:00',
#    'timeRemaining': '20:00',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 11,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8484144,
#     'winningPlayerId': 8479420,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 58,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:28',
#    'timeRemaining': '19:32',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 13,
#    'details': {'xCoord': -38,
#     'yCoord': 25,
#     'zoneCode': 'O',
#     'reason': 'wide-right',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8481568,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 8,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:42',
#    'timeRemaining': '19:18',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 15,
#    'details': {'reason': 'referee-or-linesman',
#     'secondaryReason': 'player-injury'}},
#   {'eventId': 60,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:42',
#    'timeRemaining': '19:18',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 18,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8477987,
#     'winningPlayerId': 8480802,
#     'xCoord': -20,
#     'yCoord': 22,
#     'zoneCode': 'N'}},
#   {'eventId': 75,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:55',
#    'timeRemaining': '19:05',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 19,
#    'details': {'xCoord': 96,
#     'yCoord': 14,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8475722,
#     'hitteePlayerId': 8476473}},
#   {'eventId': 64,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '00:59',
#    'timeRemaining': '19:01',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 20,
#    'details': {'xCoord': 38,
#     'yCoord': -40,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8479982,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 0,
#     'homeSOG': 1}},
#   {'eventId': 65,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:04',
#    'timeRemaining': '18:56',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 21,
#    'details': {'xCoord': -62,
#     'yCoord': 8,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8482703,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 1,
#     'homeSOG': 1}},
#   {'eventId': 9,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:15',
#    'timeRemaining': '18:45',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 23,
#    'details': {'reason': 'offside'}},
#   {'eventId': 67,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:15',
#    'timeRemaining': '18:45',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 26,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483493,
#     'winningPlayerId': 8483500,
#     'xCoord': 20,
#     'yCoord': 22,
#     'zoneCode': 'N'}},
#   {'eventId': 71,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:27',
#    'timeRemaining': '18:33',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 27,
#    'details': {'xCoord': -74,
#     'yCoord': -37,
#     'zoneCode': 'O',
#     'reason': 'wide-right',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8476882,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 99,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:34',
#    'timeRemaining': '18:26',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 28,
#    'details': {'xCoord': -97,
#     'yCoord': -7,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'playerId': 8483493}},
#   {'eventId': 98,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:42',
#    'timeRemaining': '18:18',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 30,
#    'details': {'xCoord': 71,
#     'yCoord': 40,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8482896,
#     'hitteePlayerId': 8481568}},
#   {'eventId': 106,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '01:46',
#    'timeRemaining': '18:14',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 32,
#    'details': {'xCoord': 79,
#     'yCoord': -30,
#     'zoneCode': 'O',
#     'playerId': 8481522,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 83,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:23',
#    'timeRemaining': '17:37',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 40,
#    'details': {'xCoord': 84,
#     'yCoord': 4,
#     'zoneCode': 'O',
#     'blockingPlayerId': 8479359,
#     'shootingPlayerId': 8480807,
#     'eventOwnerTeamId': 7,
#     'reason': 'teammate-blocked'}},
#   {'eventId': 108,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:30',
#    'timeRemaining': '17:30',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 41,
#    'details': {'xCoord': 41,
#     'yCoord': -39,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8481522,
#     'hitteePlayerId': 8482172}},
#   {'eventId': 120,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:37',
#    'timeRemaining': '17:23',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 43,
#    'details': {'xCoord': 72,
#     'yCoord': 38,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8479359,
#     'hitteePlayerId': 8484783}},
#   {'eventId': 116,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '02:51',
#    'timeRemaining': '17:09',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 50,
#    'details': {'xCoord': -89,
#     'yCoord': -16,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'playerId': 8480839}},
#   {'eventId': 128,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:01',
#    'timeRemaining': '16:59',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 51,
#    'details': {'xCoord': -95,
#     'yCoord': 11,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8480807,
#     'hitteePlayerId': 8477479}},
#   {'eventId': 95,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:09',
#    'timeRemaining': '16:51',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 52,
#    'details': {'xCoord': -71,
#     'yCoord': 0,
#     'zoneCode': 'O',
#     'typeCode': 'MIN',
#     'descKey': 'tripping',
#     'duration': 2,
#     'committedByPlayerId': 8484144,
#     'drawnByPlayerId': 8479420,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 91,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:09',
#    'timeRemaining': '16:51',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 56,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8479420,
#     'winningPlayerId': 8476882,
#     'xCoord': 69,
#     'yCoord': -22,
#     'zoneCode': 'D'}},
#   {'eventId': 151,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:33',
#    'timeRemaining': '16:27',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 57,
#    'details': {'xCoord': 50,
#     'yCoord': -3,
#     'zoneCode': 'O',
#     'shotType': 'slap',
#     'shootingPlayerId': 8479420,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 1,
#     'homeSOG': 2}},
#   {'eventId': 12,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:34',
#    'timeRemaining': '16:26',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 58,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 101,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:34',
#    'timeRemaining': '16:26',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 60,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8479420,
#     'winningPlayerId': 8483450,
#     'xCoord': 69,
#     'yCoord': -22,
#     'zoneCode': 'D'}},
#   {'eventId': 11,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:41',
#    'timeRemaining': '16:19',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 61,
#    'details': {'reason': 'offside'}},
#   {'eventId': 104,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '03:41',
#    'timeRemaining': '16:19',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 62,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483450,
#     'winningPlayerId': 8479420,
#     'xCoord': 20,
#     'yCoord': 22,
#     'zoneCode': 'N'}},
#   {'eventId': 115,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:21',
#    'timeRemaining': '15:39',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 69,
#    'details': {'xCoord': 72,
#     'yCoord': 32,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8481806,
#     'shootingPlayerId': 8480839,
#     'eventOwnerTeamId': 7,
#     'reason': 'blocked'}},
#   {'eventId': 13,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:22',
#    'timeRemaining': '15:38',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 70,
#    'details': {'reason': 'puck-in-netting'}},
#   {'eventId': 117,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:22',
#    'timeRemaining': '15:38',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 73,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483493,
#     'winningPlayerId': 8480802,
#     'xCoord': 69,
#     'yCoord': 22,
#     'zoneCode': 'O'}},
#   {'eventId': 152,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:28',
#    'timeRemaining': '15:32',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 74,
#    'details': {'xCoord': 77,
#     'yCoord': 5,
#     'zoneCode': 'O',
#     'reason': 'wide-right',
#     'shotType': 'tip-in',
#     'shootingPlayerId': 8477949,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 123,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:41',
#    'timeRemaining': '15:19',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 75,
#    'details': {'xCoord': 81,
#     'yCoord': 16,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8477949,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 1,
#     'homeSOG': 3}},
#   {'eventId': 125,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '04:58',
#    'timeRemaining': '15:02',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 76,
#    'details': {'xCoord': 63,
#     'yCoord': 13,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8481524,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 1,
#     'homeSOG': 4}},
#   {'eventId': 126,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:06',
#    'timeRemaining': '14:54',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 77,
#    'details': {'xCoord': 64,
#     'yCoord': -24,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8480802,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 1,
#     'homeSOG': 5}},
#   {'eventId': 213,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:25',
#    'timeRemaining': '14:35',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 84,
#    'details': {'xCoord': -33,
#     'yCoord': -30,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'playerId': 8479982}},
#   {'eventId': 14,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:57',
#    'timeRemaining': '14:03',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 87,
#    'details': {'reason': 'icing'}},
#   {'eventId': 136,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:57',
#    'timeRemaining': '14:03',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 89,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8483500,
#     'winningPlayerId': 8484144,
#     'xCoord': 69,
#     'yCoord': 22,
#     'zoneCode': 'D'}},
#   {'eventId': 139,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '05:59',
#    'timeRemaining': '14:01',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 90,
#    'details': {'xCoord': 35,
#     'yCoord': 30,
#     'zoneCode': 'O',
#     'shotType': 'slap',
#     'shootingPlayerId': 8480839,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 1,
#     'homeSOG': 6}},
#   {'eventId': 15,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:06',
#    'timeRemaining': '13:54',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 91,
#    'details': {'reason': 'icing'}},
#   {'eventId': 140,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:06',
#    'timeRemaining': '13:54',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 92,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8483500,
#     'winningPlayerId': 8484144,
#     'xCoord': 69,
#     'yCoord': 22,
#     'zoneCode': 'D'}},
#   {'eventId': 226,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:16',
#    'timeRemaining': '13:44',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 93,
#    'details': {'xCoord': 97,
#     'yCoord': -1,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8477479}},
#   {'eventId': 142,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '06:16',
#    'timeRemaining': '13:44',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 94,
#    'details': {'xCoord': 82,
#     'yCoord': 18,
#     'zoneCode': 'O',
#     'reason': 'wide-left',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8482896,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 227,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:06',
#    'timeRemaining': '12:54',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 104,
#    'details': {'xCoord': 28,
#     'yCoord': -18,
#     'zoneCode': 'D',
#     'playerId': 8482176,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 230,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:07',
#    'timeRemaining': '12:53',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 525,
#    'typeDescKey': 'takeaway',
#    'sortOrder': 105,
#    'details': {'xCoord': 42,
#     'yCoord': -23,
#     'zoneCode': 'O',
#     'playerId': 8477949,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 202,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:16',
#    'timeRemaining': '12:44',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 106,
#    'details': {'xCoord': 3,
#     'yCoord': 22,
#     'zoneCode': 'N',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8477987,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 2,
#     'homeSOG': 6}},
#   {'eventId': 234,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:27',
#    'timeRemaining': '12:33',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 114,
#    'details': {'xCoord': 41,
#     'yCoord': 6,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8481806}},
#   {'eventId': 243,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:43',
#    'timeRemaining': '12:17',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 117,
#    'details': {'xCoord': 37,
#     'yCoord': -10,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8476882}},
#   {'eventId': 214,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:51',
#    'timeRemaining': '12:09',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 118,
#    'details': {'xCoord': 70,
#     'yCoord': 16,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8482671,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 2,
#     'homeSOG': 7}},
#   {'eventId': 215,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '07:56',
#    'timeRemaining': '12:04',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 119,
#    'details': {'xCoord': 80,
#     'yCoord': 3,
#     'zoneCode': 'O',
#     'blockingPlayerId': 8475722,
#     'shootingPlayerId': 8482671,
#     'eventOwnerTeamId': 7,
#     'reason': 'teammate-blocked'}},
#   {'eventId': 16,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:03',
#    'timeRemaining': '11:57',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 535,
#    'typeDescKey': 'delayed-penalty',
#    'sortOrder': 120,
#    'details': {'eventOwnerTeamId': 7}},
#   {'eventId': 222,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:09',
#    'timeRemaining': '11:51',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 124,
#    'details': {'xCoord': 71,
#     'yCoord': 6,
#     'zoneCode': 'O',
#     'typeCode': 'MIN',
#     'descKey': 'slashing',
#     'duration': 2,
#     'committedByPlayerId': 8475722,
#     'drawnByPlayerId': 8483493,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 17,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:09',
#    'timeRemaining': '11:51',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 126,
#    'details': {'reason': 'tv-timeout', 'secondaryReason': 'tv-timeout'}},
#   {'eventId': 218,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:09',
#    'timeRemaining': '11:51',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 129,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483493,
#     'winningPlayerId': 8480802,
#     'xCoord': -69,
#     'yCoord': 22,
#     'zoneCode': 'D'}},
#   {'eventId': 246,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:12',
#    'timeRemaining': '11:48',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 130,
#    'details': {'xCoord': -79,
#     'yCoord': 36,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'playerId': 8480807}},
#   {'eventId': 18,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:29',
#    'timeRemaining': '11:31',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 131,
#    'details': {'reason': 'puck-in-crowd'}},
#   {'eventId': 228,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '08:29',
#    'timeRemaining': '11:31',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 132,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483493,
#     'winningPlayerId': 8480802,
#     'xCoord': -20,
#     'yCoord': 22,
#     'zoneCode': 'N'}},
#   {'eventId': 236,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '09:35',
#    'timeRemaining': '10:25',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 136,
#    'details': {'xCoord': -59,
#     'yCoord': 14,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8481524,
#     'shootingPlayerId': 8484144,
#     'eventOwnerTeamId': 16,
#     'reason': 'blocked'}},
#   {'eventId': 239,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:03',
#    'timeRemaining': '09:57',
#    'situationCode': '1541',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 139,
#    'details': {'xCoord': -78,
#     'yCoord': -5,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8483493,
#     'shootingPlayerId': 8484144,
#     'eventOwnerTeamId': 16,
#     'reason': 'teammate-blocked'}},
#   {'eventId': 19,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:10',
#    'timeRemaining': '09:50',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 141,
#    'details': {'reason': 'high-stick', 'secondaryReason': 'tv-timeout'}},
#   {'eventId': 240,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:10',
#    'timeRemaining': '09:50',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 144,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8477987,
#     'winningPlayerId': 8482896,
#     'xCoord': -69,
#     'yCoord': 22,
#     'zoneCode': 'D'}},
#   {'eventId': 250,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '10:23',
#    'timeRemaining': '09:37',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 145,
#    'details': {'xCoord': 97,
#     'yCoord': -23,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8482896,
#     'hitteePlayerId': 8481806}},
#   {'eventId': 265,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:04',
#    'timeRemaining': '08:56',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 146,
#    'details': {'xCoord': -49,
#     'yCoord': 40,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8477949,
#     'hitteePlayerId': 8481806}},
#   {'eventId': 271,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:07',
#    'timeRemaining': '08:53',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 148,
#    'details': {'xCoord': -66,
#     'yCoord': 40,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8479420,
#     'hitteePlayerId': 8481624}},
#   {'eventId': 293,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '11:55',
#    'timeRemaining': '08:05',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 157,
#    'details': {'xCoord': 70,
#     'yCoord': -42,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8478043}},
#   {'eventId': 258,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:00',
#    'timeRemaining': '08:00',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 158,
#    'details': {'xCoord': 38,
#     'yCoord': -20,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8482671,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 2,
#     'homeSOG': 8}},
#   {'eventId': 20,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:02',
#    'timeRemaining': '07:58',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 159,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 259,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:02',
#    'timeRemaining': '07:58',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 162,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8476882,
#     'winningPlayerId': 8480802,
#     'xCoord': 69,
#     'yCoord': -22,
#     'zoneCode': 'O'}},
#   {'eventId': 263,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:04',
#    'timeRemaining': '07:56',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 163,
#    'details': {'xCoord': 29,
#     'yCoord': -23,
#     'zoneCode': 'O',
#     'reason': 'wide-left',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8481524,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 264,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '12:11',
#    'timeRemaining': '07:49',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 164,
#    'details': {'xCoord': 72,
#     'yCoord': 6,
#     'zoneCode': 'O',
#     'blockingPlayerId': 8480802,
#     'shootingPlayerId': 8479982,
#     'eventOwnerTeamId': 7,
#     'reason': 'teammate-blocked'}},
#   {'eventId': 299,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:00',
#    'timeRemaining': '07:00',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 174,
#    'details': {'xCoord': 64,
#     'yCoord': 39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8484144}},
#   {'eventId': 276,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:01',
#    'timeRemaining': '06:59',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 175,
#    'details': {'xCoord': 76,
#     'yCoord': 4,
#     'zoneCode': 'O',
#     'shotType': 'deflected',
#     'shootingPlayerId': 8481522,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 2,
#     'homeSOG': 9}},
#   {'eventId': 278,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:17',
#    'timeRemaining': '06:43',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 177,
#    'details': {'xCoord': 49,
#     'yCoord': -20,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8481522,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 2,
#     'homeSOG': 10}},
#   {'eventId': 351,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:20',
#    'timeRemaining': '06:40',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 178,
#    'details': {'xCoord': 63,
#     'yCoord': 41,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'playerId': 8484783}},
#   {'eventId': 300,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:26',
#    'timeRemaining': '06:34',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 181,
#    'details': {'xCoord': 0,
#     'yCoord': -41,
#     'zoneCode': 'N',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8479359,
#     'hitteePlayerId': 8484144}},
#   {'eventId': 285,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:40',
#    'timeRemaining': '06:20',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 188,
#    'details': {'xCoord': 69,
#     'yCoord': 13,
#     'zoneCode': 'O',
#     'reason': 'hit-crossbar',
#     'shotType': 'snap',
#     'shootingPlayerId': 8477949,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7}},
#   {'eventId': 289,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:49',
#    'timeRemaining': '06:11',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 189,
#    'details': {'xCoord': 86,
#     'yCoord': -7,
#     'zoneCode': 'O',
#     'shotType': 'backhand',
#     'shootingPlayerId': 8479420,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 2,
#     'homeSOG': 11}},
#   {'eventId': 551,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:56',
#    'timeRemaining': '06:04',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 190,
#    'details': {'xCoord': 78,
#     'yCoord': -1,
#     'zoneCode': 'O',
#     'shotType': 'tip-in',
#     'shootingPlayerId': 8482659,
#     'goalieInNetId': 8482821,
#     'eventOwnerTeamId': 7,
#     'awaySOG': 2,
#     'homeSOG': 12}},
#   {'eventId': 290,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:57',
#    'timeRemaining': '06:03',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 191,
#    'details': {'xCoord': 86,
#     'yCoord': -5,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'scoringPlayerId': 8482659,
#     'scoringPlayerTotal': 6,
#     'assist1PlayerId': 8479420,
#     'assist1PlayerTotal': 9,
#     'assist2PlayerId': 8477949,
#     'assist2PlayerTotal': 10,
#     'eventOwnerTeamId': 7,
#     'goalieInNetId': 8482821,
#     'awayScore': 0,
#     'homeScore': 1,
#     'highlightClipSharingUrl': 'https://nhl.com/video/chi-buf-doan-scores-goal-against-arvid-soderblom-6385427265112',
#     'highlightClipSharingUrlFr': 'https://nhl.com/fr/video/chi-buf-doan-marque-un-but-contre-arvid-soderblom-6385425724112',
#     'highlightClip': 6385427265112,
#     'highlightClipFr': 6385425724112,
#     'discreteClip': 6385427372112,
#     'discreteClipFr': 6385426397112},
#    'pptReplayUrl': 'https://wsr.nhle.com/sprites/20252026/2025020331/ev290.json'},
#   {'eventId': 291,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '13:57',
#    'timeRemaining': '06:03',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 194,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8484144,
#     'winningPlayerId': 8482896,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 21,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:03',
#    'timeRemaining': '05:57',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 195,
#    'details': {'reason': 'puck-in-benches', 'secondaryReason': 'tv-timeout'}},
#   {'eventId': 296,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:03',
#    'timeRemaining': '05:57',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 197,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8484144,
#     'winningPlayerId': 8482896,
#     'xCoord': 20,
#     'yCoord': 22,
#     'zoneCode': 'N'}},
#   {'eventId': 363,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:26',
#    'timeRemaining': '05:34',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 198,
#    'details': {'xCoord': -98,
#     'yCoord': 18,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8478043,
#     'hitteePlayerId': 8479982}},
#   {'eventId': 380,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:28',
#    'timeRemaining': '05:32',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 199,
#    'details': {'xCoord': -98,
#     'yCoord': 23,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'playerId': 8479982}},
#   {'eventId': 367,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:39',
#    'timeRemaining': '05:21',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 202,
#    'details': {'xCoord': 97,
#     'yCoord': 11,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'hittingPlayerId': 8482896,
#     'hitteePlayerId': 8482176}},
#   {'eventId': 373,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '14:43',
#    'timeRemaining': '05:17',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 203,
#    'details': {'xCoord': 68,
#     'yCoord': -39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8478043,
#     'hitteePlayerId': 8482765}},
#   {'eventId': 377,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:10',
#    'timeRemaining': '04:50',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 209,
#    'details': {'xCoord': 65,
#     'yCoord': -39,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 16,
#     'hittingPlayerId': 8476891,
#     'hitteePlayerId': 8480802}},
#   {'eventId': 359,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:19',
#    'timeRemaining': '04:41',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 210,
#    'details': {'xCoord': 71,
#     'yCoord': 10,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'scoringPlayerId': 8475722,
#     'scoringPlayerTotal': 5,
#     'assist1PlayerId': 8482097,
#     'assist1PlayerTotal': 6,
#     'assist2PlayerId': 8480839,
#     'assist2PlayerTotal': 14,
#     'eventOwnerTeamId': 7,
#     'goalieInNetId': 8482821,
#     'awayScore': 0,
#     'homeScore': 2,
#     'highlightClipSharingUrl': 'https://nhl.com/video/chi-buf-zucker-scores-goal-against-arvid-soderblom-6385425903112',
#     'highlightClipSharingUrlFr': 'https://nhl.com/fr/video/chi-buf-zucker-marque-un-but-contre-arvid-soderblom-6385425120112',
#     'highlightClip': 6385425903112,
#     'highlightClipFr': 6385425120112,
#     'discreteClip': 6385426777112,
#     'discreteClipFr': 6385426971112},
#    'pptReplayUrl': 'https://wsr.nhle.com/sprites/20252026/2025020331/ev359.json'},
#   {'eventId': 360,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:19',
#    'timeRemaining': '04:41',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 213,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483493,
#     'winningPlayerId': 8481522,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 370,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:40',
#    'timeRemaining': '04:20',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 509,
#    'typeDescKey': 'penalty',
#    'sortOrder': 214,
#    'details': {'xCoord': 95,
#     'yCoord': -1,
#     'zoneCode': 'D',
#     'typeCode': 'MIN',
#     'descKey': 'high-sticking',
#     'duration': 2,
#     'committedByPlayerId': 8484783,
#     'drawnByPlayerId': 8478413,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 365,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '15:40',
#    'timeRemaining': '04:20',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 218,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483450,
#     'winningPlayerId': 8479420,
#     'xCoord': 69,
#     'yCoord': -22,
#     'zoneCode': 'O'}},
#   {'eventId': 376,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:22',
#    'timeRemaining': '03:38',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 221,
#    'details': {'xCoord': 72,
#     'yCoord': 0,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8481568,
#     'shootingPlayerId': 8479420,
#     'eventOwnerTeamId': 7,
#     'reason': 'blocked'}},
#   {'eventId': 472,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '16:31',
#    'timeRemaining': '03:29',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 222,
#    'details': {'xCoord': 31,
#     'yCoord': 6,
#     'zoneCode': 'D',
#     'eventOwnerTeamId': 7,
#     'playerId': 8480839}},
#   {'eventId': 383,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:06',
#    'timeRemaining': '02:54',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 508,
#    'typeDescKey': 'blocked-shot',
#    'sortOrder': 227,
#    'details': {'xCoord': 57,
#     'yCoord': -11,
#     'zoneCode': 'D',
#     'blockingPlayerId': 8476882,
#     'shootingPlayerId': 8482659,
#     'eventOwnerTeamId': 7,
#     'reason': 'blocked'}},
#   {'eventId': 388,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:33',
#    'timeRemaining': '02:27',
#    'situationCode': '1451',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 505,
#    'typeDescKey': 'goal',
#    'sortOrder': 231,
#    'details': {'xCoord': 81,
#     'yCoord': 4,
#     'zoneCode': 'O',
#     'shotType': 'tip-in',
#     'scoringPlayerId': 8481524,
#     'scoringPlayerTotal': 4,
#     'assist1PlayerId': 8477949,
#     'assist1PlayerTotal': 11,
#     'assist2PlayerId': 8480802,
#     'assist2PlayerTotal': 6,
#     'eventOwnerTeamId': 7,
#     'goalieInNetId': 8482821,
#     'awayScore': 0,
#     'homeScore': 3,
#     'highlightClipSharingUrl': 'https://nhl.com/video/chi-buf-byram-scores-goal-against-arvid-soderblom-6385426784112',
#     'highlightClipSharingUrlFr': 'https://nhl.com/fr/video/chi-buf-byram-marque-un-but-contre-arvid-soderblom-6385425128112',
#     'highlightClip': 6385426784112,
#     'highlightClipFr': 6385425128112,
#     'discreteClip': 6385427380112,
#     'discreteClipFr': 6385426105112},
#    'pptReplayUrl': 'https://wsr.nhle.com/sprites/20252026/2025020331/ev388.json'},
#   {'eventId': 389,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:33',
#    'timeRemaining': '02:27',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 235,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8481522,
#     'winningPlayerId': 8483450,
#     'xCoord': 0,
#     'yCoord': 0,
#     'zoneCode': 'N'}},
#   {'eventId': 394,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:03',
#    'timeRemaining': '01:57',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 236,
#    'details': {'xCoord': -45,
#     'yCoord': -35,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8476891,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 3,
#     'homeSOG': 12}},
#   {'eventId': 471,
#    'periodDescriptor': {'number': 1,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '18:07',
#    'timeRemaining': '01:53',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 503,
#    'typeDescKey': 'hit',
#    'sortOrder': 237,
#    'details': {'xCoord': -72,
#     'yCoord': 39,
#     'zoneCode': 'D',
# ...
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:08',
#    'timeRemaining': '02:52',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 752,
#    'details': {'reason': 'goalie-stopped-after-sog',
#     'secondaryReason': 'tv-timeout'}},
#   {'eventId': 1020,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:08',
#    'timeRemaining': '02:52',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 755,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8480802,
#     'winningPlayerId': 8484144,
#     'xCoord': -69,
#     'yCoord': 22,
#     'zoneCode': 'O'}},
#   {'eventId': 1045,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:25',
#    'timeRemaining': '02:35',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 756,
#    'details': {'xCoord': -59,
#     'yCoord': 27,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'playerId': 8484783}},
#   {'eventId': 1024,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:44',
#    'timeRemaining': '02:16',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 507,
#    'typeDescKey': 'missed-shot',
#    'sortOrder': 757,
#    'details': {'xCoord': -69,
#     'yCoord': 27,
#     'zoneCode': 'O',
#     'reason': 'high-and-wide-right',
#     'shotType': 'snap',
#     'shootingPlayerId': 8484144,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16}},
#   {'eventId': 409,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:46',
#    'timeRemaining': '02:14',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 758,
#    'details': {'reason': 'puck-in-crowd'}},
#   {'eventId': 1025,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:46',
#    'timeRemaining': '02:14',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 761,
#    'details': {'eventOwnerTeamId': 16,
#     'losingPlayerId': 8482896,
#     'winningPlayerId': 8478043,
#     'xCoord': -69,
#     'yCoord': 22,
#     'zoneCode': 'O'}},
#   {'eventId': 1029,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '17:47',
#    'timeRemaining': '02:13',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 762,
#    'details': {'xCoord': -42,
#     'yCoord': 28,
#     'zoneCode': 'O',
#     'shotType': 'wrist',
#     'shootingPlayerId': 8476473,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 19,
#     'homeSOG': 21}},
#   {'eventId': 1046,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:03',
#    'timeRemaining': '00:57',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 770,
#    'details': {'xCoord': -77,
#     'yCoord': -39,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 16,
#     'playerId': 8481624}},
#   {'eventId': 1038,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:09',
#    'timeRemaining': '00:51',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 506,
#    'typeDescKey': 'shot-on-goal',
#    'sortOrder': 771,
#    'details': {'xCoord': -49,
#     'yCoord': 40,
#     'zoneCode': 'O',
#     'shotType': 'snap',
#     'shootingPlayerId': 8481806,
#     'goalieInNetId': 8480045,
#     'eventOwnerTeamId': 16,
#     'awaySOG': 20,
#     'homeSOG': 21}},
#   {'eventId': 410,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:12',
#    'timeRemaining': '00:48',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 516,
#    'typeDescKey': 'stoppage',
#    'sortOrder': 772,
#    'details': {'reason': 'goalie-stopped-after-sog'}},
#   {'eventId': 1039,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:12',
#    'timeRemaining': '00:48',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 502,
#    'typeDescKey': 'faceoff',
#    'sortOrder': 775,
#    'details': {'eventOwnerTeamId': 7,
#     'losingPlayerId': 8483493,
#     'winningPlayerId': 8480802,
#     'xCoord': -69,
#     'yCoord': 22,
#     'zoneCode': 'D'}},
#   {'eventId': 1047,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '19:23',
#    'timeRemaining': '00:37',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 504,
#    'typeDescKey': 'giveaway',
#    'sortOrder': 776,
#    'details': {'xCoord': 88,
#     'yCoord': -6,
#     'zoneCode': 'O',
#     'eventOwnerTeamId': 7,
#     'playerId': 8482097}},
#   {'eventId': 411,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 521,
#    'typeDescKey': 'period-end',
#    'sortOrder': 777},
#   {'eventId': 415,
#    'periodDescriptor': {'number': 3,
#     'periodType': 'REG',
#     'maxRegulationPeriods': 3},
#    'timeInPeriod': '20:00',
#    'timeRemaining': '00:00',
#    'situationCode': '1551',
#    'homeTeamDefendingSide': 'left',
#    'typeCode': 524,
#    'typeDescKey': 'game-end',
#    'sortOrder': 781}],
#  'rosterSpots': [{'teamId': 7,
#    'playerId': 8475722,
#    'firstName': {'default': 'Jason'},
#    'lastName': {'default': 'Zucker'},
#    'sweaterNumber': 17,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8475722.png'},
#   {'teamId': 16,
#    'playerId': 8476473,
#    'firstName': {'default': 'Connor'},
#    'lastName': {'default': 'Murphy'},
#    'sweaterNumber': 5,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8476473.png'},
#   {'teamId': 16,
#    'playerId': 8476882,
#    'firstName': {'default': 'Teuvo'},
#    'lastName': {'default': 'Teravainen',
#     'cs': 'Teräväinen',
#     'fi': 'Teräväinen',
#     'sk': 'Teräväinen',
#     'sv': 'Teräväinen'},
#    'sweaterNumber': 86,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8476882.png'},
#   {'teamId': 16,
#    'playerId': 8476891,
#    'firstName': {'default': 'Matt'},
#    'lastName': {'default': 'Grzelcyk'},
#    'sweaterNumber': 48,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8476891.png'},
#   {'teamId': 16,
#    'playerId': 8477479,
#    'firstName': {'default': 'Tyler'},
#    'lastName': {'default': 'Bertuzzi'},
#    'sweaterNumber': 59,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8477479.png'},
#   {'teamId': 7,
#    'playerId': 8477949,
#    'firstName': {'default': 'Alex'},
#    'lastName': {'default': 'Tuch'},
#    'sweaterNumber': 89,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8477949.png'},
#   {'teamId': 16,
#    'playerId': 8477987,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'Donato'},
#    'sweaterNumber': 8,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8477987.png'},
#   {'teamId': 16,
#    'playerId': 8478043,
#    'firstName': {'default': 'Sam'},
#    'lastName': {'default': 'Lafferty'},
#    'sweaterNumber': 24,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8478043.png'},
#   {'teamId': 7,
#    'playerId': 8478413,
#    'firstName': {'default': 'Jordan'},
#    'lastName': {'default': 'Greenway'},
#    'sweaterNumber': 12,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8478413.png'},
#   {'teamId': 7,
#    'playerId': 8479312,
#    'firstName': {'default': 'Alex'},
#    'lastName': {'default': 'Lyon'},
#    'sweaterNumber': 34,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8479312.png'},
#   {'teamId': 7,
#    'playerId': 8479359,
#    'firstName': {'default': 'Beck'},
#    'lastName': {'default': 'Malenstyn'},
#    'sweaterNumber': 29,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8479359.png'},
#   {'teamId': 7,
#    'playerId': 8479420,
#    'firstName': {'default': 'Tage'},
#    'lastName': {'default': 'Thompson'},
#    'sweaterNumber': 72,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8479420.png'},
#   {'teamId': 7,
#    'playerId': 8479982,
#    'firstName': {'default': 'Conor'},
#    'lastName': {'default': 'Timmins'},
#    'sweaterNumber': 21,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8479982.png'},
#   {'teamId': 7,
#    'playerId': 8480045,
#    'firstName': {'default': 'Ukko-Pekka'},
#    'lastName': {'default': 'Luukkonen'},
#    'sweaterNumber': 1,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8480045.png'},
#   {'teamId': 7,
#    'playerId': 8480196,
#    'firstName': {'default': 'Jacob'},
#    'lastName': {'default': 'Bryson'},
#    'sweaterNumber': 78,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8480196.png'},
#   {'teamId': 7,
#    'playerId': 8480802,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'McLeod'},
#    'sweaterNumber': 71,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8480802.png'},
#   {'teamId': 7,
#    'playerId': 8480807,
#    'firstName': {'default': 'Mattias'},
#    'lastName': {'default': 'Samuelsson'},
#    'sweaterNumber': 23,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8480807.png'},
#   {'teamId': 7,
#    'playerId': 8480839,
#    'firstName': {'default': 'Rasmus'},
#    'lastName': {'default': 'Dahlin'},
#    'sweaterNumber': 26,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8480839.png'},
#   {'teamId': 16,
#    'playerId': 8481519,
#    'firstName': {'default': 'Spencer'},
#    'lastName': {'default': 'Knight'},
#    'sweaterNumber': 30,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8481519.png'},
#   {'teamId': 7,
#    'playerId': 8481522,
#    'firstName': {'default': 'Peyton'},
#    'lastName': {'default': 'Krebs'},
#    'sweaterNumber': 19,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8481522.png'},
#   {'teamId': 7,
#    'playerId': 8481524,
#    'firstName': {'default': 'Bowen'},
#    'lastName': {'default': 'Byram'},
#    'sweaterNumber': 4,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8481524.png'},
#   {'teamId': 16,
#    'playerId': 8481568,
#    'firstName': {'default': 'Alex'},
#    'lastName': {'default': 'Vlasic'},
#    'sweaterNumber': 72,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8481568.png'},
#   {'teamId': 16,
#    'playerId': 8481624,
#    'firstName': {'default': 'Ilya', 'cs': 'Ilja', 'fi': 'Ilja', 'sk': 'Iľja'},
#    'lastName': {'default': 'Mikheyev',
#     'cs': 'Michejev',
#     'fi': 'Mihejev',
#     'sk': 'Michejev'},
#    'sweaterNumber': 95,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8481624.png'},
#   {'teamId': 16,
#    'playerId': 8481806,
#    'firstName': {'default': 'Louis'},
#    'lastName': {'default': 'Crevier'},
#    'sweaterNumber': 46,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8481806.png'},
#   {'teamId': 7,
#    'playerId': 8482097,
#    'firstName': {'default': 'Jack'},
#    'lastName': {'default': 'Quinn'},
#    'sweaterNumber': 22,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8482097.png'},
#   {'teamId': 16,
#    'playerId': 8482172,
#    'firstName': {'default': 'Landon'},
#    'lastName': {'default': 'Slaggert'},
#    'sweaterNumber': 84,
#    'positionCode': 'L',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8482172.png'},
#   {'teamId': 16,
#    'playerId': 8482176,
#    'firstName': {'default': 'Wyatt'},
#    'lastName': {'default': 'Kaiser'},
#    'sweaterNumber': 44,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8482176.png'},
#   {'teamId': 7,
#    'playerId': 8482659,
#    'firstName': {'default': 'Josh'},
#    'lastName': {'default': 'Doan'},
#    'sweaterNumber': 91,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8482659.png'},
#   {'teamId': 7,
#    'playerId': 8482671,
#    'firstName': {'default': 'Owen'},
#    'lastName': {'default': 'Power'},
#    'sweaterNumber': 25,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8482671.png'},
#   {'teamId': 16,
#    'playerId': 8482703,
#    'firstName': {'default': 'Colton'},
#    'lastName': {'default': 'Dach'},
#    'sweaterNumber': 34,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8482703.png'},
#   {'teamId': 7,
#    'playerId': 8482765,
#    'firstName': {'default': 'Isak'},
#    'lastName': {'default': 'Rosen'},
#    'sweaterNumber': 63,
#    'positionCode': 'R',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8482765.png'},
#   {'teamId': 16,
#    'playerId': 8482821,
#    'firstName': {'default': 'Arvid'},
#    'lastName': {'default': 'Soderblom',
#     'cs': 'Söderblom',
#     'fi': 'Söderblom',
#     'sk': 'Söderblom',
#     'sv': 'Söderblom'},
#    'sweaterNumber': 40,
#    'positionCode': 'G',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8482821.png'},
#   {'teamId': 7,
#    'playerId': 8482896,
#    'firstName': {'default': 'Tyson'},
#    'lastName': {'default': 'Kozak'},
#    'sweaterNumber': 48,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8482896.png'},
#   {'teamId': 16,
#    'playerId': 8483450,
#    'firstName': {'default': 'Ryan'},
#    'lastName': {'default': 'Greene'},
#    'sweaterNumber': 20,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8483450.png'},
#   {'teamId': 16,
#    'playerId': 8483493,
#    'firstName': {'default': 'Frank'},
#    'lastName': {'default': 'Nazar'},
#    'sweaterNumber': 91,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8483493.png'},
#   {'teamId': 7,
#    'playerId': 8483500,
#    'firstName': {'default': 'Noah'},
#    'lastName': {'default': 'Ostlund'},
#    'sweaterNumber': 86,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/BUF/8483500.png'},
#   {'teamId': 16,
#    'playerId': 8483506,
#    'firstName': {'default': 'Sam'},
#    'lastName': {'default': 'Rinzel'},
#    'sweaterNumber': 6,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8483506.png'},
#   {'teamId': 16,
#    'playerId': 8484144,
#    'firstName': {'default': 'Connor'},
#    'lastName': {'default': 'Bedard'},
#    'sweaterNumber': 98,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8484144.png'},
#   {'teamId': 16,
#    'playerId': 8484197,
#    'firstName': {'default': 'Oliver'},
#    'lastName': {'default': 'Moore'},
#    'sweaterNumber': 11,
#    'positionCode': 'C',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8484197.png'},
#   {'teamId': 16,
#    'playerId': 8484783,
#    'firstName': {'default': 'Artyom'},
#    'lastName': {'default': 'Levshunov'},
#    'sweaterNumber': 55,
#    'positionCode': 'D',
#    'headshot': 'https://assets.nhle.com/mugs/nhl/20252026/CHI/8484783.png'}],
#  'regPeriods': 3,
#  'summary': {}}

# %%
types = set()
for play in client.game_center.play_by_play(2025020331)["plays"]:
    types.add(play["typeDescKey"])

# %%
types
# Out:
# {'blocked-shot',
#  'delayed-penalty',
#  'faceoff',
#  'game-end',
#  'giveaway',
#  'goal',
#  'hit',
#  'missed-shot',
#  'penalty',
#  'period-end',
#  'period-start',
#  'shot-on-goal',
#  'stoppage',
#  'takeaway'}

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon

fig, ax = plt.subplots(figsize=(10,6))

# High danger zone (rectangle)
high = Polygon([[69, -6], [69, 6], [89, 6], [89, -6]], color='red', alpha=0.5, label='High Danger')
ax.add_patch(high)

# Medium danger zone (trapezoid) - right side
# Line points for the trapezoid
x1, y1 = 89, 6
x2, y2 = 69, 22

# Upper trapezoid vertices (top and bottom)
med_trap_upper = [[x2, y2], [x1, y1], [x1, 6], [x2, 6]]  # upper right trapezoid
med_trap_lower = [[x2, -y2], [x1, -y1], [x1, -6], [x2, -6]]  # mirrored below center

med_upper = Polygon(med_trap_upper, color='orange', alpha=0.5, label='Medium Danger')
med_lower = Polygon(med_trap_lower, color='orange', alpha=0.5)

ax.add_patch(med_upper)
ax.add_patch(med_lower)

# Medium center rectangle (44 <= x < 69)
med_center_upper = Polygon([[44, 0], [69, 0], [69, 22], [44, 22]], color='orange', alpha=0.5)
med_center_lower = Polygon([[44, 0], [69, 0], [69, -22], [44, -22]], color='orange', alpha=0.5)

ax.add_patch(med_center_upper)
ax.add_patch(med_center_lower)

# Axes and labels
ax.set_xlim(40, 95)
ax.set_ylim(-25, 25)
ax.set_xlabel("x (distance from goal line)")
ax.set_ylabel("y (distance from center line)")
ax.set_title("Hockey Danger Zones")
ax.grid(True)

# Legend
ax.legend(handles=[high, med_upper], labels=['High Danger', 'Medium Danger'])

plt.show()

# %%
from itertools import product
import pandas as pd
import logging
from tqdm import tqdm

# We will need to scrape play-by-play data for the desired information, since we are doing this we might as well build new xG models to try and add more features. Create a class for the scraper.
class NHLShotScraper:

    def __init__(self, seasons=[20232024, 20242025, 20252026]):
        self.client = NHLClient()
        self.seasons = seasons
        self.game_ids = set()
        self.player_dict = {}
        self.player_stats_cache = {}

        self.logger = logging.getLogger("NHLShotScraper")
        self.logger.setLevel(logging.INFO)
        if not self.logger.handlers:
            ch = logging.StreamHandler()
            ch.setLevel(logging.INFO)
            formatter = logging.Formatter("%(asctime)s [%(levelname)s] %(message)s")
            ch.setFormatter(formatter)
            self.logger.addHandler(ch)

        logging.getLogger("urllib3").setLevel(logging.WARNING)
        logging.getLogger("httpx").setLevel(logging.WARNING)

        self.logger.info("NHLShotScraper initialized")
        
    def second_diff(self, time1, time2):
        """Calculates the time difference between the occurrence of two events."""
        m1, s1 = int(time1[:2]), int(time1[3:5])
        m2, s2 = int(time2[:2]), int(time2[3:5])
        return abs((m2*60 + s2) - (m1*60 + s1))
    
    def get_game_ids(self):
        """Fetches game_ids with caching."""
        teams = self.client.teams.teams_info()
        team_abbrs = []

        team_abbrs = [team["abbr"] for team in teams]

        for abbrev, season in product(team_abbrs, self.seasons):
            if abbrev == "UTA" and season < 20242025:
                abbrev = "ARI"

            games = self.client.schedule.team_season_schedule(team_abbr=abbrev, season=season)["games"]
            self.game_ids.update(game["id"] for game in games if game["gameType"] != 1)

        return list(self.game_ids)
    
    def get_player_stats(self, player_id):
        """Fetch player stats with caching."""
        if player_id in self.player_dict:
            return self.player_dict[player_id], self.player_stats_cache[player_id]

        player_info = self.client.stats.player_career_stats(player_id)

        name = player_info["firstName"]["default"] + " " + player_info["lastName"]["default"]

        if player_info["position"] == "G":
            stats = [
                player_info["position"],
                player_info["shootsCatches"],
                player_info["featuredStats"]["regularSeason"]["career"].get("savePctg", None)
            ]
        else:
            stats = [
                player_info["position"],
                player_info["shootsCatches"],
                player_info["featuredStats"]["regularSeason"]["career"].get("shootingPctg", None)
            ]

        self.player_dict[player_id] = name
        self.player_stats_cache[player_id] = stats

        return name, stats

    def is_rebound(self, play, prev_play):
        """Determines if a shot is a rebound or not."""
        if not prev_play:
            return 0
        time_diff = self.second_diff(play["timeInPeriod"], prev_play["timeInPeriod"])
        if prev_play["typeDescKey"] == "blocked-shot" and time_diff <= 2:
            return 1
        if prev_play["typeDescKey"] in ["missed-shot", "shot-on-goal"] and time_diff <= 3:
            return 1
        return 0
    
    def is_rush(self, play, prev_play):
        """Determines if a shot is a rush chance or not"""
        if not prev_play:
            return 0
        
        stoppages = {"stoppage", "faceoff", "goal", "penalty", "period-start", "period-end", "game-end"}
        
        if prev_play["typeDescKey"] in stoppages:
            return 0
        
        time_diff = self.second_diff(play["timeInPeriod"], prev_play["timeInPeriod"])
        if time_diff > 4:
            return 0
        
        shooting_team_id = play["details"]["eventOwnerTeamId"]
        prev_zone = prev_play["details"]["zoneCode"]
        prev_owner = prev_play["details"]["eventOwnerTeamId"]

        if prev_zone == "N":
            return 1
        elif prev_zone == "D" and prev_owner == shooting_team_id:
            return 1
        elif prev_zone == "O" and prev_owner != shooting_team_id:
            return 1
        
        return 0

    def get_danger_zone(self, x, y):
        """
        Classify a shot as being in high, medium, or low danger zones. Zone calculation based on Zones defined by War-on-Ice.
        """

        x_abs = abs(x)
        y_abs = abs(y)

        if 69 <= x_abs <= 89 and y_abs <= 6:
            return "high"
         
        elif 69 <= x_abs <= 89 and 6 < y_abs <= 22:
            y_boundary = -0.8*x_abs + 77.2
            if y_abs <= y_boundary:
                return "med"
            else:
                 return "low"
            
        elif 44 <= x_abs < 69 and y_abs <= 22:
            return "med"
        else:
            return "low"


    def scrape_fenwick_shots(self, game_ids):
        """Takes in a list of game ids and scrapes the play-by-play for that game to create a DataFrame of Fenwick shot events."""
        rows = []

        for game_id in tqdm(game_ids, desc="Scraping games"):
            try:
                game_data = self.client.game_center.play_by_play(game_id=game_id)
            except Exception as e:
                return pd.DataFrame()

            home_id = game_data["homeTeam"]["id"]
            away_id = game_data["awayTeam"]["id"]
            pbp = game_data["plays"]

            for idx, play in enumerate(pbp):
                if play["typeDescKey"] not in {"missed-shot", "goal", "shot-on-goal"}:
                    continue

                try:
                    team_id = play["details"]["eventOwnerTeamId"]
                    home = int(team_id == home_id)
                    away = int(team_id == away_id)

                    if (home == 1 and play["situationCode"][0] == "0") or (away == 1 and play["situationCode"][3] == "0"):
                        continue

                    shooter_id = (
                        play["details"].get("scoringPlayerId")
                        if play["typeDescKey"] == "goal"
                        else play["details"].get("shootingPlayerId")
                    )
                    if shooter_id is None:
                        continue

                    shooter, shooter_stats = self.get_player_stats(shooter_id)

                    prev_play = pbp[idx - 1] if idx > 0 else None
                    rebound = self.is_rebound(play, prev_play)
                    rush = self.is_rush(play, prev_play)

                    x = play["details"].get("xCoord")
                    y = play["details"].get("yCoord")
                    if x is None or y is None:
                        continue
                    danger = self.get_danger_zone(x, y)

                    # Situations
                    home_skaters = int(play["situationCode"][2])
                    away_skaters = int(play["situationCode"][1])
                    shot_type = play["details"].get("shotType")
                    shot_class = play["typeDescKey"]
                    zone = play["details"].get("zoneCode")

                    # Goalie
                    goalie_id = play["details"].get("goalieInNetId")
                    if goalie_id:
                        goalie, goalie_stats = self.get_player_stats(goalie_id)
                    else:
                        goalie = None
                        goalie_stats = [None, None, None]

                    rows.append({
                    "game_id": game_id,
                    "team_id": team_id,
                    "home": home,
                    "last_play": prev_play["typeDescKey"] if prev_play else None,
                    "rebound": rebound,
                    "rush": rush,
                    "home_skaters": home_skaters,
                    "away_skaters": away_skaters,
                    "x_coord": x,
                    "y_coord": y,
                    "shooter_id": shooter_id,
                    "shooter": shooter,
                    "position": shooter_stats[0],
                    "shoots": shooter_stats[1],
                    "career_shooting_pct": shooter_stats[2],
                    "goalie_id": goalie_id,
                    "goalie": goalie,
                    "goalie_catches": goalie_stats[1],
                    "career_save_pct": goalie_stats[2],
                    "shot_type": shot_type,
                    "zone": zone,
                    "shot_class": shot_class,
                    "danger_zone": danger,
                })

                except Exception as e:
                    logging.warning(f"Error processing play in game {game_id}: {e}")
                    continue

        return pd.DataFrame(rows)

# %%
test = NHLShotScraper()

test.scrape_fenwick_shots([2025020331])
# Out:
# 2025-11-23 00:11:17,596 [INFO] NHLShotScraper initialized
# 2025-11-23 00:11:17,596 [INFO] NHLShotScraper initialized
# Scraping games: 100%|██████████| 1/1 [00:06<00:00,  6.40s/it]
#        game_id  team_id  home     last_play  rebound  rush  home_skaters  \
# 0   2025020331       16     0       faceoff        0     0             5
# 1   2025020331        7     1           hit        0     0             5
# 2   2025020331       16     0  shot-on-goal        0     0             5
# 3   2025020331       16     0       faceoff        0     0             5
# 4   2025020331        7     1       faceoff        0     0             5
# ..         ...      ...   ...           ...      ...   ...           ...
# 68  2025020331       16     0      giveaway        0     0             5
# 69  2025020331       16     0  shot-on-goal        1     0             5
# 70  2025020331       16     0      giveaway        0     0             5
# 71  2025020331       16     0       faceoff        0     0             5
# 72  2025020331       16     0      giveaway        0     0             5
#
#     away_skaters  x_coord  y_coord  ...  shoots career_shooting_pct goalie_id  \
# 0              5      -38       25  ...       L              0.0430   8480045
# 1              5       38      -40  ...       R              0.0357   8482821
# 2              5      -62        8  ...       L              0.0740   8480045
# 3              5      -74      -37  ...       L              0.1105   8480045
# 4              4       50       -3  ...       R              0.1358   8482821
# ..           ...      ...      ...  ...     ...                 ...       ...
# 68             5      -58      -27  ...       L              0.0740   8480045
# 69             5      -61       37  ...       R              0.1176   8480045
# 70             5      -69       27  ...       R              0.1228   8480045
# 71             5      -42       28  ...       R              0.0437   8480045
# 72             5      -49       40  ...       R              0.0724   8480045
#
#                   goalie  goalie_catches  career_save_pct shot_type zone  \
# 0   Ukko-Pekka Luukkonen               L         0.897722     wrist    O
# 1        Arvid Soderblom               L         0.888769     wrist    O
# 2   Ukko-Pekka Luukkonen               L         0.897722      snap    O
# 3   Ukko-Pekka Luukkonen               L         0.897722     wrist    O
# 4        Arvid Soderblom               L         0.888769      slap    O
# ..                   ...             ...              ...       ...  ...
# 68  Ukko-Pekka Luukkonen               L         0.897722     wrist    O
# 69  Ukko-Pekka Luukkonen               L         0.897722      slap    O
# 70  Ukko-Pekka Luukkonen               L         0.897722      snap    O
# 71  Ukko-Pekka Luukkonen               L         0.897722     wrist    O
# 72  Ukko-Pekka Luukkonen               L         0.897722      snap    O
#
#       shot_class danger_zone
# 0    missed-shot         low
# 1   shot-on-goal         low
# 2   shot-on-goal         med
# 3    missed-shot         low
# 4   shot-on-goal         med
# ..           ...         ...
# 68  shot-on-goal         low
# 69   missed-shot         low
# 70   missed-shot         low
# 71  shot-on-goal         low
# 72  shot-on-goal         low
#
# [73 rows x 23 columns]
